# %%
from redcap import Project
import pandas
import pandas_profiling
p = Project("https://cdsweb07.fhcrc.org/redcap/api/index.php?pid=450", "BD39A4A247755C00F8BC7EFE72089C35")
form = 'patient_id'

# %%
print(p.forms)
# Out:
# ('treatment_event', 'graft_rejection', 'vital_status', 'prehct1_treatment', 'response_or_relapse_event', 'gvhd', 'patient_id', 'primary_prophylaxis_against_relapse', 'immunosuppression_kinetics')

# %%
df = p.export_records(forms=[form], format='df')
if form != 'vital_status' and form != 'patient_id':
    df = df.loc[df['redcap_repeat_instrument'].notnull()]

# %%
df.describe()
# Out:
#        redcap_repeat_instrument  redcap_repeat_instance     hct1_dx  \
# count                       0.0                     0.0  345.000000
# mean                        NaN                     NaN    1.089855
# std                         NaN                     NaN    0.686698
# min                         NaN                     NaN    1.000000
# 25%                         NaN                     NaN    1.000000
# 50%                         NaN                     NaN    1.000000
# 75%                         NaN                     NaN    1.000000
# max                         NaN                     NaN    8.000000
#
#        al_origin___1  al_origin___2  al_origin___3  hct1_stage___1  \
# count     346.000000     346.000000     346.000000      346.000000
# mean        0.667630       0.280347       0.112717        0.297688
# std         0.471745       0.449819       0.316704        0.457904
# min         0.000000       0.000000       0.000000        0.000000
# ...

# %%
df['vital_status_complete']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\whiteau\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vital_status_complete'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-d580b7bd4c14> in <module>()
# ...

# %%
df.isna().sum()
length = df.shape[0]
print("Empty columns:")
num_na = 0
empty_cols = [col for col in list(df) if df[col].isna().sum() == length]
print("length, width {}, number of empty columns: {}".format(df.shape, len(empty_cols)))
# Out:
# Empty columns:
# length, width (346, 10), number of empty columns: 2

# %%
df.head(10)
# Out:
#             redcap_repeat_instrument  redcap_repeat_instance  e_status  \
# subject_id
# 0244017                          NaN                     NaN       1.0
# 0277965                          NaN                     NaN       1.0
# 0742011                          NaN                     NaN       1.0
# 1962960                          NaN                     NaN       1.0
# 2015958                          NaN                     NaN       1.0
# 2060522                          NaN                     NaN       2.0
# 2097045                          NaN                     NaN       1.0
# 2114653                          NaN                     NaN       1.0
# 2146388                          NaN                     NaN       1.0
# 2156305                          NaN                     NaN       1.0
#
#            date_status  w_status_dead  w_status_alive  \
# subject_id
# 0244017     2011-09-22            1.0             NaN
# ...
